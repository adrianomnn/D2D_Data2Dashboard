# %% [markdown]
# ### EXP 01: Harvard Stimulation Data _ Harnow

# %%
# This script shows how to call `run_domain_detector`
# and save / print the results with detailed history visualization

import os
import sys
import json
import pandas as pd
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import seaborn as sns

# # ------------------------------------------------------------------
# # 1. Make sure Python can find your agent package / module
# #    (adapt the path if your repo layout is different)
# # ------------------------------------------------------------------
ROOT_DIR = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
sys.path.append(ROOT_DIR)

from agents.d2insight_agent_sys import run_domain_detector   # noqa: E402

# d2insight_agent_sys 
# d2insight_agent_sys

# %%
def visualize_history(result):
    """
    Visualize the domain detection history across iterations.
    
    Args:
        result: The result from run_domain_detector
    """
    if not result or "history" not in result or not result["history"]:
        print("No history data available")
        return
    
    # Convert history to DataFrame for easier manipulation
    history_df = pd.DataFrame(result["history"])
    
    # Print a nice tabular summary
    print("\n=== DOMAIN DETECTION HISTORY ===")
    
    for i, entry in enumerate(result["history"]):
        iteration = entry.get("iteration", i)
        print(f"\n📊 ITERATION {iteration}")
        print(f"📌 Domain: {entry.get('domain', 'Unknown')}")
        
        # Format scores if they exist
        scores = entry.get("scores", {})
        if scores:
            print("📈 Scores:")
            for score_name, score_value in scores.items():
                stars = "★" * score_value + "☆" * (4 - score_value)
                print(f"   {score_name.ljust(15)}: {stars} ({score_value}/4)")
                
        # Print analysis snippet
        analysis_head = entry.get("analysis_head", "")
        if analysis_head:
            print(f"📝 Analysis: {analysis_head}...")
            
    # Plot score evolution if more than one iteration with scores
    scored_entries = [entry for entry in result["history"] if entry.get("scores")]
    if len(scored_entries) > 1:
        plt.figure(figsize=(10, 6))
        
        # Prepare data for plotting
        iterations = []
        score_data = {}
        
        for entry in scored_entries:
            iter_num = entry.get("iteration", 0)
            iterations.append(iter_num)
            
            for score_name, score_value in entry.get("scores", {}).items():
                if score_name not in score_data:
                    score_data[score_name] = []
                score_data[score_name].append(score_value)
        
        # Plot each score metric
        for score_name, values in score_data.items():
            plt.plot(iterations, values, marker='o', label=score_name)
            
        plt.title("Evolution of Scores Across Iterations")
        plt.xlabel("Iteration")
        plt.ylabel("Score (0-4)")
        plt.ylim(0, 4.5)
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.legend()
        plt.tight_layout()
        plt.xticks(iterations)  # Set x-axis ticks to integer iterations
        plt.show()

def run_and_visualize(csv_path, max_cycles=5):
    """
    Run domain detector and visualize results with history.
    
    Args:
        csv_path: Path to the CSV file
        max_cycles: Maximum number of improvement cycles
    
    Returns:
        The complete result from the domain detector
    """
    print(f"🚀 Running domain detector on {csv_path} with max_cycles={max_cycles}")
    
    # Run the domain detector
    result = run_domain_detector(csv_path, max_cycles)
    
    # Visualize history
    visualize_history(result)
    
    # Print final results
    if "analysis" in result:
        analysis = result["analysis"]
        print("\n=== FINAL RESULTS ===")
        print(f"✅ Domain: {analysis.get('domain', 'Unknown')}")
        print(f"✅ Core Concepts: {', '.join(analysis.get('core_concepts', []))}")
        
        if "analysis" in analysis:
            print("\n📊 DESCRIPTIVE ANALYSIS:")
            print(analysis["analysis"].get("descriptive", ""))
            
            print("\n🔮 PREDICTIVE ANALYSIS:")
            print(analysis["analysis"].get("predictive", ""))
            
            print("\n🌐 DOMAIN-RELATED ANALYSIS:")
            print(analysis["analysis"].get("domain_related", ""))
    
    return result

# %%
# Example usage:
result = run_and_visualize("https://drive.google.com/uc?export=download&id=1JhsgpIulCv8Q9NPTZGhrz5-y_RUufMoO", max_cycles=5)

result
# Out:
# 🚀 Running domain detector on https://drive.google.com/uc?export=download&id=1JhsgpIulCv8Q9NPTZGhrz5-y_RUufMoO with max_cycles=5
# Successfully read CSV: 3117 rows, 19 columns
# Data profile built successfully
# Starting analysis with max_cycles=5
# domain_node state: {'memory': '[]', 'iteration': 0, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}]}
# concept_node state: {'memory': '[]', 'iteration': 0, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) refers to the practices, strategies, and technologies that companies use to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}}
# analysis_node state: {'memory': '[]', 'iteration': 0, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) refers to the practices, strategies, and technologies that companies use to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels']}]}
# eval_node state: {'memory': '[]', 'iteration': 0, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) refers to the practices, strategies, and technologies that companies use to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels']}], 'analysis': {'domain': 'Customer Relationship Management (CRM)', 'core_concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels'], 'analysis': {'descriptive': "The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationship management. The 'Current Period' is constant at 9, indicating a snapshot of customer data at a specific time. 'Customer ID' is unique for each record, serving as a primary key. The 'Periods Active' ranges from 1 to 14, with an average of approximately 2 periods, suggesting that most customers are relatively new. The 'Current Customer (Y/N)' field shows a mix of active and inactive customers, with a slight skew towards inactive ones. The 'Acquisition Channel' and 'Sector' fields are predominantly 'External' and 'Aerospace', respectively, indicating a focused market strategy. Revenue-related fields show a wide range, with 'Revenue, Total' averaging around 56,569, but with significant variability, as indicated by a high standard deviation. The 'Expected CLV' also varies widely, suggesting diverse customer value potential across the dataset.", 'predictive': "Analyzing the dataset for predictive insights, the 'Expected CLV' could be influenced by factors such as 'Periods Active', 'Acquisition Channel', and 'Premium (Y/N)'. Customers acquired through 'Internal' channels or those marked as 'Premium' might exhibit higher CLV, suggesting a potential focus area for increasing customer value. Additionally, the number of 'Maker' and 'Advanced' contracts could serve as indicators of future revenue potential, as customers with more contracts might have higher engagement and thus higher CLV. Predictive models could leverage these variables to forecast customer retention and revenue growth, enabling targeted marketing strategies to enhance customer lifetime value.", 'domain_related': "In the CRM domain, understanding customer acquisition and retention is crucial. The dataset reveals that most customers are acquired externally, which might imply higher acquisition costs. However, the presence of 'Premium' customers suggests a segment that could be nurtured for higher retention and value. The 'Region' and 'Co. Age' fields provide additional segmentation opportunities, as different regions or company ages might respond differently to CRM strategies. The data suggests a potential strategy of focusing on converting 'External' acquisitions into 'Premium' customers, thereby increasing retention and maximizing CLV. Additionally, the high variability in 'Expected CLV' indicates that personalized CRM strategies could be beneficial, tailoring approaches based on customer-specific data to optimize engagement and revenue."}}}
# Decision point – iteration 1, scores: {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}
# 🔄 Analysis needs improvement (iteration 1)
# reflect_node state: {'memory': '[]', 'iteration': 0, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) refers to the practices, strategies, and technologies that companies use to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels']}], 'analysis': {'domain': 'Customer Relationship Management (CRM)', 'core_concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels'], 'analysis': {'descriptive': "The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationship management. The 'Current Period' is constant at 9, indicating a snapshot of customer data at a specific time. 'Customer ID' is unique for each record, serving as a primary key. The 'Periods Active' ranges from 1 to 14, with an average of approximately 2 periods, suggesting that most customers are relatively new. The 'Current Customer (Y/N)' field shows a mix of active and inactive customers, with a slight skew towards inactive ones. The 'Acquisition Channel' and 'Sector' fields are predominantly 'External' and 'Aerospace', respectively, indicating a focused market strategy. Revenue-related fields show a wide range, with 'Revenue, Total' averaging around 56,569, but with significant variability, as indicated by a high standard deviation. The 'Expected CLV' also varies widely, suggesting diverse customer value potential across the dataset.", 'predictive': "Analyzing the dataset for predictive insights, the 'Expected CLV' could be influenced by factors such as 'Periods Active', 'Acquisition Channel', and 'Premium (Y/N)'. Customers acquired through 'Internal' channels or those marked as 'Premium' might exhibit higher CLV, suggesting a potential focus area for increasing customer value. Additionally, the number of 'Maker' and 'Advanced' contracts could serve as indicators of future revenue potential, as customers with more contracts might have higher engagement and thus higher CLV. Predictive models could leverage these variables to forecast customer retention and revenue growth, enabling targeted marketing strategies to enhance customer lifetime value.", 'domain_related': "In the CRM domain, understanding customer acquisition and retention is crucial. The dataset reveals that most customers are acquired externally, which might imply higher acquisition costs. However, the presence of 'Premium' customers suggests a segment that could be nurtured for higher retention and value. The 'Region' and 'Co. Age' fields provide additional segmentation opportunities, as different regions or company ages might respond differently to CRM strategies. The data suggests a potential strategy of focusing on converting 'External' acquisitions into 'Premium' customers, thereby increasing retention and maximizing CLV. Additionally, the high variability in 'Expected CLV' indicates that personalized CRM strategies could be beneficial, tailoring approaches based on customer-specific data to optimize engagement and revenue. ...
# domain_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}]', 'iteration': 1, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) refers to the practices, strategies, and technologies that companies use to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels']}], 'analysis': {'domain': 'Customer Relationship Management (CRM)', 'core_concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels'], 'analysis': {'descriptive': "The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationship management. The 'Current Period' is constant at 9, indicating a snapshot of customer data at a specific time. 'Customer ID' is unique for each record, serving as a primary key. The 'Periods Active' ranges from 1 to 14, with an average of approximately 2 periods, suggesting that most customers are relatively new. The 'Current Customer (Y/N)' field shows a mix of active and inactive customers, with a slight skew towards inactive ones. The 'Acquisition Channel' and 'Sector' fields are predominantly 'External' and 'Aerospace', respectively, indicating a focused market strategy. Revenue-related fields show a wide range, with 'Revenue, Total' averaging around 56,569, but with significant variability, as indicated by a high standard deviation. The 'Expected CLV' also varies widely, suggesting diverse customer value potential across the dataset.", 'predictive': "Analyzing the dataset for predictive insights, the 'Expected CLV' could be influenced by factors such as 'Periods Active', 'Acquisition Channel', and 'Premium (Y/N)'. Customers acquired through 'Internal' channels or those marked as 'Premium' might exhibit higher CLV, suggesting a potential focus area for increasing customer value. Additionally, the number of 'Maker' and 'Advanced' contracts could serve as indicators of future revenue potential, as customers with more contracts might have higher engagement and thus higher CLV. Predictive models could leverage these variables to forecast customer retention and revenue growth, enabling targeted marketing strategies to enhance customer lifetime value.", 'domain_related': "In the CRM domain, understanding customer acquisition and retention is crucial. The dataset reveals that most customers are acquired externally, which might imply higher acquisition costs. However, the presence of 'Premium' customers suggests a segment that could be nurtured for higher retention and value. The 'Region' and 'Co. Age' fields provide additional segmentation opportunities, as different regions or company ages might respond differently to CRM stra ...
# concept_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}]', 'iteration': 1, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}], 'domain_info': {'domain': 'Customer Relationship Management', 'definition': "Customer Relationship Management (CRM) is a strategy for managing an organization's relationships and interactions with potential and current customers, often utilizing data analysis to improve business relationships.", 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels']}], 'analysis': {'domain': 'Customer Relationship Management (CRM)', 'core_concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels'], 'analysis': {'descriptive': "The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationship management. The 'Current Period' is constant at 9, indicating a snapshot of customer data at a specific time. 'Customer ID' is unique for each record, serving as a primary key. The 'Periods Active' ranges from 1 to 14, with an average of approximately 2 periods, suggesting that most customers are relatively new. The 'Current Customer (Y/N)' field shows a mix of active and inactive customers, with a slight skew towards inactive ones. The 'Acquisition Channel' and 'Sector' fields are predominantly 'External' and 'Aerospace', respectively, indicating a focused market strategy. Revenue-related fields show a wide range, with 'Revenue, Total' averaging around 56,569, but with significant variability, as indicated by a high standard deviation. The 'Expected CLV' also varies widely, suggesting diverse customer value potential across the dataset.", 'predictive': "Analyzing the dataset for predictive insights, the 'Expected CLV' could be influenced by factors such as 'Periods Active', 'Acquisition Channel', and 'Premium (Y/N)'. Customers acquired through 'Internal' channels or those marked as 'Premium' might exhibit higher CLV, suggesting a potential focus area for increasing customer value. Additionally, the number of 'Maker' and 'Advanced' contracts could serve as indicators of future revenue potential, as customers with more contracts might have higher engagement and thus higher CLV. Predictive models could leverage these variables to forecast customer retention and revenue growth, enabling targeted marketing strategies to enhance customer lifetime value.", 'domain_related': "In the CRM domain, understanding customer acquisition and retention is crucial. The dataset reveals that most customers are acquired externally, which might imply higher acquisition costs. However, the presence of 'Premium' customers suggests a segment that could be nurtured for higher retention and value. The 'Region' and 'Co. Age' fields provide additional segmentation opportunities, as different regions or company ages might respond differently to CRM strategies. The data suggests a potential strategy of focusing on converting 'External' acquisitions into 'Prem ...
# analysis_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}]', 'iteration': 1, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}], 'domain_info': {'domain': 'Customer Relationship Management', 'definition': "Customer Relationship Management (CRM) is a strategy for managing an organization's relationships and interactions with potential and current customers, often utilizing data analysis to improve business relationships.", 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management (CRM)', 'core_concepts': ['Customer Lifetime Value (CLV)', 'Customer Acquisition', 'Customer Retention', 'Revenue Segmentation', 'Customer Segmentation', 'Acquisition Channels'], 'analysis': {'descriptive': "The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationship management. The 'Current Period' is constant at 9, indicating a snapshot of customer data at a specific time. 'Customer ID' is unique for each record, serving as a primary key. The 'Periods Active' ranges from 1 to 14, with an average of approximately 2 periods, suggesting that most customers are relatively new. The 'Current Customer (Y/N)' field shows a mix of active and inactive customers, with a slight skew towards inactive ones. The 'Acquisition Channel' and 'Sector' fields are predominantly 'External' and 'Aerospace', respectively, indicating a focused market strategy. Revenue-related fields show a wide range, with 'Revenue, Total' averaging around 56,569, but with significant variability, as indicated by a high standard deviation. The 'Expected CLV' also varies widely, suggesting diverse customer value potential across the dataset.", 'predictive': "Analyzing the dataset for predictive insights, the 'Expected CLV' could be influenced by factors such as 'Periods Active', 'Acquisition Channel', and 'Premium (Y/N)'. Customers acquired through 'Internal' channels or those marked as 'Premium' might exhibit higher CLV, suggesting a potential focus area for increasing customer value. Additionally, the number of 'Maker' and 'Advanced' contracts could serve as indicators of future revenue potential, as customers with more contracts might have higher engagement and thus higher CLV. Predictive models could leverage these variables to forecast customer retention and revenue growth, enabling targeted marketing strategies to enhance customer lifetime value.", 'domain_related': "In the CRM domain, understanding customer acquisition and retention is crucial. The dataset reveals that most customers are acquired externally, which might imply higher acquisition costs. However, the presence of 'Premium' customers suggests a segment that could be nurtured for higher retention and value. The 'Region' and 'Co. Age' fields provide additional segmentation opportunities, as different regions or company ages might respond differently to CRM strategies. The data suggests a potential strategy of focusing on converting 'External' acquisitions into 'Premium' cust ...
# eval_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}]', 'iteration': 1, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}], 'domain_info': {'domain': 'Customer Relationship Management', 'definition': "Customer Relationship Management (CRM) is a strategy for managing an organization's relationships and interactions with potential and current customers, often utilizing data analysis to improve business relationships.", 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management', 'core_concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis'], 'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includes 3,117 records with 19 attributes, capturing details such as customer activity periods, acquisition channels, and revenue metrics. Notably, the 'Current Customer (Y/N)' column indicates a significant churn rate, with many customers no longer active. The 'Revenue, Total' column shows a wide range of revenue contributions, suggesting diverse customer value. The 'Expected CLV' column, with its high variance, highlights the potential for targeted customer retention strategies.", 'predictive': "Predictive analysis could focus on identifying factors that influence customer churn and lifetime value. The correlation between 'Periods Active' and 'Expected CLV' suggests that longer engagement may lead to higher lifetime value. Additionally, the 'Acquisition Channel' and 'Region' variables could be pivotal in predicting customer retention, as different channels and regions may exhibit varying churn rates. Machine learning models could be employed to predict churn probability and optimize acquisition strategies, potentially increasing retention and maximizing CLV.", 'domain_related': "In the CRM domain, understanding customer behavior and optimizing interactions are crucial. The dataset's insights into acquisition channels and customer segmentation can inform targeted marketing efforts. For instance, customers acquired through 'Internal' channels might exhibit different retention patterns compared to those acquired 'Externally.' Furthermore, the 'Sector' and 'Size' attributes can aid in segmenting customers for personalized engagement strategies. By leveraging these insights, businesses can enhance customer satisfaction, reduce churn, and ultimately drive revenue growth."}}, 'evaluation': 'The evaluation assesses the accuracy and comprehensiveness of domain labels and concepts, as well as the depth and actionability of the analysis.', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'domain_ok': True, 'concepts_ok': True}
# Decision point – iteration 2, scores: {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}
# 🔄 Analysis needs improvement (iteration 2)
# reflect_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}]', 'iteration': 1, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}, {'iteration': 1, 'domain': 'Customer Relationship Management', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}, 'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includ'}], 'domain_info': {'domain': 'Customer Relationship Management', 'definition': "Customer Relationship Management (CRM) is a strategy for managing an organization's relationships and interactions with potential and current customers, often utilizing data analysis to improve business relationships.", 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management', 'core_concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis'], 'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includes 3,117 records with 19 attributes, capturing details such as customer activity periods, acquisition channels, and revenue metrics. Notably, the 'Current Customer (Y/N)' column indicates a significant churn rate, with many customers no longer active. The 'Revenue, Total' column shows a wide range of revenue contributions, suggesting diverse customer value. The 'Expected CLV' column, with its high variance, highlights the potential for targeted customer retention strategies.", 'predictive': "Predictive analysis could focus on identifying factors that influence customer churn and lifetime value. The correlation between 'Periods Active' and 'Expected CLV' suggests that longer engagement may lead to higher lifetime value. Additionally, the 'Acquisition Channel' and 'Region' variables could be pivotal in predicting customer retention, as different channels and regions may exhibit varying churn rates. Machine learning models could be employed to predict churn probability and optimize acquisition strategies, potentially increasing retention and maximizing CLV.", 'domain_related': "In the CRM domain, understanding customer behavior and optimizing interactions are crucial. The dataset's insights into acquisition channels and customer segmentation can inform targeted marketing efforts. For instance, customers acquired through 'Internal' channels might exhibit different retention patterns compared to those acquired 'Externally.' Furthermore, the 'Sector' and 'Size' attributes can aid in segmenting customers for personalized engagement strategies. By leveraging these insights, businesses can enhance customer satisfaction, reduce churn, and ultimately drive revenue growth."}}, 'evaluation': 'The evaluation assesses the accuracy and comprehensiveness of domain labels and concepts, as well as the depth and actionability of the analysis.', 'scores': {'correctness': 4, 'relevan ...
# domain_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered.", "Insightfulness: Increase the depth of analysis by providing more detailed explanations and connections between concepts, offering a clearer understanding of their implications.", "Novelty: Introduce unique perspectives or lesser-known insights that can add value to the evaluation, distinguishing it from more common analyses."]}]', 'iteration': 2, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}, {'iteration': 1, 'domain': 'Customer Relationship Management', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}, 'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includ'}], 'domain_info': {'domain': 'Customer Relationship Management', 'definition': "Customer Relationship Management (CRM) is a strategy for managing an organization's relationships and interactions with potential and current customers, often utilizing data analysis to improve business relationships.", 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management', 'core_concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis'], 'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includes 3,117 records with 19 attributes, capturing details such as customer activity periods, acquisition channels, and revenue metrics. Notably, the 'Current Customer (Y/N)' column indicates a significant churn rate, with many customers no longer active. The 'Revenue, Total' column shows a wide range of revenue contributions, suggesting diverse customer value. The 'Expected CLV' column, with its high variance, highlights the potential for targeted customer retention strategies.", 'predictive': "Predictive analysis could focus on identifying factors that influence customer churn and lifetime value. The correlation between 'Periods Active' and 'Expected CLV' suggests that longer engagement may lead to higher lifetime value. Additionally, the 'Acquisition Channel' and 'Region' variables could be pivotal in predicting customer retention, as different channels and regions may exhibit varying churn rates. Machine learning models could be employed to predict churn probability and optimize acquisition strategies, potentially increasing retention and maximizing CLV.", 'domain_related': "In the CRM domain, understanding cus ...
# concept_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered.", "Insightfulness: Increase the depth of analysis by providing more detailed explanations and connections between concepts, offering a clearer understanding of their implications.", "Novelty: Introduce unique perspectives or lesser-known insights that can add value to the evaluation, distinguishing it from more common analyses."]}]', 'iteration': 2, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}, {'iteration': 1, 'domain': 'Customer Relationship Management', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}, 'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includ'}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) is a strategy and technology used by companies to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management', 'core_concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis'], 'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includes 3,117 records with 19 attributes, capturing details such as customer activity periods, acquisition channels, and revenue metrics. Notably, the 'Current Customer (Y/N)' column indicates a significant churn rate, with many customers no longer active. The 'Revenue, Total' column shows a wide range of revenue contributions, suggesting diverse customer value. The 'Expected CLV' column, with its high variance, highlights the potential for targeted customer retention strategies.", 'predictive': "Predictive analysis could focus on identifying factors that influence customer churn and lifetime value. The correlation between 'Periods Active' and 'Expected CLV' suggests that longer engagement may lead to higher lifetime value. Additionally, the 'Acquisition Channel' and 'Region' variables could be pivotal in predicting customer retention, as different channels and regions may exhibit varying churn rates. Machine learning models could be employed to predict churn probability and optimize acquisition strategies, potentially increasing rete ...
# analysis_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered.", "Insightfulness: Increase the depth of analysis by providing more detailed explanations and connections between concepts, offering a clearer understanding of their implications.", "Novelty: Introduce unique perspectives or lesser-known insights that can add value to the evaluation, distinguishing it from more common analyses."]}]', 'iteration': 2, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}, {'iteration': 1, 'domain': 'Customer Relationship Management', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}, 'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includ'}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) is a strategy and technology used by companies to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention Strategies', 'Acquisition Channels', 'Customer Churn Analysis', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management', 'core_concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention', 'Acquisition Channels', 'Customer Churn', 'Revenue Analysis'], 'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includes 3,117 records with 19 attributes, capturing details such as customer activity periods, acquisition channels, and revenue metrics. Notably, the 'Current Customer (Y/N)' column indicates a significant churn rate, with many customers no longer active. The 'Revenue, Total' column shows a wide range of revenue contributions, suggesting diverse customer value. The 'Expected CLV' column, with its high variance, highlights the potential for targeted customer retention strategies.", 'predictive': "Predictive analysis could focus on identifying factors that influence customer churn and lifetime value. The correlation between 'Periods Active' and 'Expected CLV' suggests that longer engagement may lead to higher lifetime value. Additionally, the 'Acquisition Channel' and 'Region' variables could be pivotal in predicting customer retention, as different channels and regions may exhibit varying churn rates. Machine learning models could be employed to predict churn probability and optimize acquisition strategies, potent ...
# eval_node state: {'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered.", "Insightfulness: Increase the depth of analysis by providing more detailed explanations and connections between concepts, offering a clearer understanding of their implications.", "Novelty: Introduce unique perspectives or lesser-known insights that can add value to the evaluation, distinguishing it from more common analyses."]}]', 'iteration': 2, 'max_cycles': 5, 'domain_fixed': False, 'previous_scores': {}, 'history': [{'iteration': 0, 'domain': 'Unknown', 'scores': {}, 'analysis_head': ''}, {'iteration': 0, 'domain': 'Customer Relationship Management (CRM)', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 4, 'novelty': 4}, 'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'}, {'iteration': 1, 'domain': 'Customer Relationship Management', 'scores': {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}, 'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includ'}], 'domain_info': {'domain': 'Customer Relationship Management (CRM)', 'definition': 'Customer Relationship Management (CRM) is a strategy and technology used by companies to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.', 'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'}, 'concepts': [{'concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention Strategies', 'Acquisition Channels', 'Customer Churn Analysis', 'Revenue Analysis']}], 'analysis': {'domain': 'Customer Relationship Management (CRM)', 'core_concepts': ['Customer Segmentation', 'Customer Lifetime Value (CLV)', 'Customer Retention Strategies', 'Acquisition Channels', 'Customer Churn Analysis', 'Revenue Analysis'], 'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and characteristics within a CRM context, featuring 3,117 records and 19 attributes. Key variables include 'Customer ID', 'Periods Active', 'Acquisition Channel', and 'Expected CLV'. The data reveals that most customers are not current, with a significant portion having been acquired externally. The 'Revenue, Total' and 'Expected CLV' columns show a wide range of values, indicating diverse customer value profiles. The dataset's categorical variables, such as 'Region' and 'Sector', suggest potential for segmentation analysis, while the numeric variables like 'Periods Active' and 'Revenue, Total' offer insights into customer engagement and financial contribution.", 'predictive': "Predictive analysis could focus on identifying factors that influence customer retention and lifetime value. The 'Periods Active' and 'Current Customer (Y/N)' variables can be used to model churn risk, while 'Acquisition Channel' and 'Premium (Y/N)' might predict customer value. A machine learning model could leverage these features to forecast 'Expected CLV', helpi ...
# Decision point – iteration 3, scores: {'correctness': 4, 'relevance': 3, 'coverage': 3, 'insightfulness': 3, 'novelty': 3}
# 🔄 Analysis needs improvement (iteration 3)
# ...
#
# 🔮 PREDICTIVE ANALYSIS:
# Predictive analysis could focus on identifying factors that contribute to higher 'Expected CLV' and customer retention. By examining correlations between 'Acquisition Channel', 'Premium (Y/N)', and 'Periods Active', we can develop models to predict customer churn and lifetime value. For instance, customers acquired through internal channels and those with premium status may exhibit higher retention rates and CLV. Additionally, analyzing the impact of 'No. Maker Contracts' and 'No. Advanced Contracts' on revenue streams could uncover strategies to optimize contract offerings and enhance customer profitability.
#
# 🌐 DOMAIN-RELATED ANALYSIS:
# In the CRM domain, understanding customer lifecycle stages and retention strategies is crucial. This dataset provides a foundation for exploring how different acquisition channels and customer demographics affect retention and sales growth. The high variance in 'Expected CLV' suggests opportunities for targeted customer service improvements and personalized marketing strategies. By leveraging CRM technologies to analyze 'Customer ID' and 'Period Acquired', companies can tailor their engagement approaches, focusing on high-value customers and optimizing resource allocation to maximize sales growth and customer satisfaction.
# {'profile': {'raw': {'n_rows': 3117,
#    'n_cols': 19,
#    'columns': {'Current Period': {'dtype': 'int64',
#      'unique_ratio': 0.0003,
#      'sample': ['9', '9', '9', '9', '9'],
#      'min': np.int64(9),
#      'max': np.int64(9),
#      'mean': np.float64(9.0),
#      'std': np.float64(0.0)},
#     'Customer ID': {'dtype': 'int64',
#      'unique_ratio': 1.0,
#      'sample': ['1432', '1433', '1447', '1448', '1449'],
#      'min': np.int64(1432),
#      'max': np.int64(4548),
#      'mean': np.float64(2990.0),
#      'std': np.float64(899.9447)},
#     'Periods Active': {'dtype': 'int64',
#      'unique_ratio': 0.0045,
#      'sample': ['1', '14', '4', '1', '2'],
#      'min': np.int64(1),
#      'max': np.int64(14),
#      'mean': np.float64(1.9673),
#      'std': np.float64(1.7232)},
#     'Current Customer (Y/N)': {'dtype': 'object',
#      'unique_ratio': 0.0006,
#      'sample': ['N', 'Y', 'N', 'N', 'N']},
#     'Period Acquired': {'dtype': 'int64',
#      'unique_ratio': 0.0045,
#      'sample': ['-5', '-5', '-4', '-4', '-4'],
#      'min': np.int64(-5),
#      'max': np.int64(8),
#      'mean': np.float64(4.5223),
#      'std': np.float64(3.5675)},
#     'Period Terminated': {'dtype': 'float64',
#      'unique_ratio': 0.0042,
#      'sample': ['-4.0', 'nan', '0.0', '-3.0', '-2.0'],
#      'min': np.float64(-4.0),
#      'max': np.float64(8.0),
#      'mean': np.float64(4.5003),
#      'std': np.float64(3.3007)},
#     'Acquisition Channel': {'dtype': 'object',
#      'unique_ratio': 0.001,
#      'sample': ['External', 'Internal', 'External', 'External', 'External']},
#     'Sector': {'dtype': 'object',
#      'unique_ratio': 0.001,
#      'sample': ['Aerospace',
#       'Aerospace',
#       'Aerospace',
#       'Aerospace',
#       'Aerospace']},
#     'Referred (Y/N)': {'dtype': 'object',
#      'unique_ratio': 0.0006,
#      'sample': ['N', 'N', 'N', 'N', 'N']},
#     'Premium (Y/N)': {'dtype': 'object',
#      'unique_ratio': 0.0006,
#      'sample': ['N', 'Y', 'N', 'N', 'N']},
#     'Region': {'dtype': 'object',
#      'unique_ratio': 0.0016,
#      'sample': ['Southeast', 'Northeast', 'Midwest', 'Northeast', 'West']},
#     'Co. Age': {'dtype': 'object',
#      'unique_ratio': 0.001,
#      'sample': ['10+yrs', '0-5yrs', '6-10yrs', '10+yrs', '0-5yrs']},
#     'Size': {'dtype': 'object',
#      'unique_ratio': 0.001,
#      'sample': ['Small', 'Medium', 'Small', 'Medium', 'Small']},
#     'No. Maker Contracts': {'dtype': 'int64',
#      'unique_ratio': 0.0032,
#      'sample': ['1', '2', '0', '2', '1'],
#      'min': np.int64(0),
#      'max': np.int64(11),
#      'mean': np.float64(1.1604),
#      'std': np.float64(1.0181)},
#     'No. Advanced Contracts': {'dtype': 'int64',
#      'unique_ratio': 0.0026,
#      'sample': ['1', '1', '2', '0', '0'],
#      'min': np.int64(0),
#      'max': np.int64(7),
#      'mean': np.float64(0.8219),
#      'std': np.float64(1.048)},
#     'Revenue, Total': {'dtype': 'int64',
#      'unique_ratio': 0.025,
#      'sample': ['50000', '104000', '58000', '42000', '21000'],
#      'min': np.int64(21000),
#      'max': np.int64(552000),
#      'mean': np.float64(56568.8162),
#      'std': np.float64(47359.6992)},
#     'Maker Revenue': {'dtype': 'int64',
#      'unique_ratio': 0.0055,
#      'sample': ['21000', '64000', '0', '42000', '21000'],
#      'min': np.int64(0),
#      'max': np.int64(352000),
#      'mean': np.float64(29305.7427),
#      'std': np.float64(27524.9544)},
#     'Advanced Revenue': {'dtype': 'int64',
#      'unique_ratio': 0.0045,
#      'sample': ['29000', '40000', '58000', '0', '0'],
#      'min': np.int64(0),
#      'max': np.int64(240000),
#      'mean': np.float64(27263.0735),
#      'std': np.float64(35739.2509)},
#     'Expected CLV': {'dtype': 'int64',
#      'unique_ratio': 0.9856,
#      'sample': ['12804', '4097127', '954922', '900272', '769466'],
#      'min': np.int64(0),
#      'max': np.int64(7066336),
#      'mean': np.float64(587519.1768),
#      'std': np.float64(1156563.109)}}},
#   'rows': 3117,
#   'cols': 19,
#   'columns': [{'name': 'Current Period',
#     'type': 'numeric',
#     'examples': ['9', '9', '9'],
#     'unit': None,
#     'min': 9,
#     'max': 9},
#    {'name': 'Customer ID',
#     'type': 'numeric',
#     'examples': ['1432', '1433', '1447'],
#     'unit': None,
#     'min': 1432,
#     'max': 4548},
#    {'name': 'Periods Active',
#     'type': 'numeric',
#     'examples': ['1', '14', '4'],
#     'unit': None,
#     'min': 1,
#     'max': 14},
#    {'name': 'Current Customer (Y/N)',
#     'type': 'categorical',
#     'examples': ['N', 'Y', 'N'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Period Acquired',
#     'type': 'numeric',
#     'examples': ['-5', '-5', '-4'],
#     'unit': None,
#     'min': -5,
#     'max': 8},
#    {'name': 'Period Terminated',
#     'type': 'numeric',
#     'examples': ['-4.0', 'nan', '0.0'],
#     'unit': None,
#     'min': -4.0,
#     'max': 8.0},
#    {'name': 'Acquisition Channel',
#     'type': 'categorical',
#     'examples': ['External', 'Internal', 'External'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Sector',
#     'type': 'categorical',
#     'examples': ['Aerospace', 'Aerospace', 'Aerospace'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Referred (Y/N)',
#     'type': 'categorical',
#     'examples': ['N', 'N', 'N'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Premium (Y/N)',
#     'type': 'categorical',
#     'examples': ['N', 'Y', 'N'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Region',
#     'type': 'categorical',
#     'examples': ['Southeast', 'Northeast', 'Midwest'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Co. Age',
#     'type': 'categorical',
#     'examples': ['10+yrs', '0-5yrs', '6-10yrs'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'Size',
#     'type': 'categorical',
#     'examples': ['Small', 'Medium', 'Small'],
#     'unit': None,
#     'min': None,
#     'max': None},
#    {'name': 'No. Maker Contracts',
#     'type': 'numeric',
#     'examples': ['1', '2', '0'],
#     'unit': None,
#     'min': 0,
#     'max': 11},
#    {'name': 'No. Advanced Contracts',
#     'type': 'numeric',
#     'examples': ['1', '1', '2'],
#     'unit': None,
#     'min': 0,
#     'max': 7},
#    {'name': 'Revenue, Total',
#     'type': 'numeric',
#     'examples': ['50000', '104000', '58000'],
#     'unit': None,
#     'min': 21000,
#     'max': 552000},
#    {'name': 'Maker Revenue',
#     'type': 'numeric',
#     'examples': ['21000', '64000', '0'],
#     'unit': None,
#     'min': 0,
#     'max': 352000},
#    {'name': 'Advanced Revenue',
#     'type': 'numeric',
#     'examples': ['29000', '40000', '58000'],
#     'unit': None,
#     'min': 0,
#     'max': 240000},
#    {'name': 'Expected CLV',
#     'type': 'numeric',
#     'examples': ['12804', '4097127', '954922'],
#     'unit': None,
#     'min': 0,
#     'max': 7066336}],
#   'formulas': [],
#   'hierarchy': '',
#   'time_series': False,
#   'candidate_pk': ['Customer ID'],
#   'possible_fk': [],
#   'subtotal_cols': [],
#   'subtotal_rows': False},
#  'memory': '[{"self_critique": ["Relevance: The analysis could be improved by ensuring that all domain labels and concepts are directly aligned with the primary focus of the evaluation, avoiding any tangential information.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered.", "Insightfulness: Increase the depth of analysis by providing more detailed explanations and connections between concepts, offering a clearer understanding of their implications.", "Novelty: Introduce unique perspectives or lesser-known insights that can add value to the evaluation, distinguishing it from more common analyses."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered.", "Insightfulness: Increase the depth of analysis by providing more detailed explanations and connections between concepts, offering a clearer understanding of their implications.", "Novelty: Introduce unique perspectives or lesser-known insights that can add value to the evaluation, distinguishing it from more common analyses."]}, {"self_critique": ["Relevance: Ensure that all domain labels and concepts are directly aligned with the primary focus of the evaluation by removing any tangential information that does not contribute to the main analysis.", "Coverage: Enhance the comprehensiveness by including additional relevant concepts and examples that provide a more complete picture of the domain being evaluated, ensuring all aspects are thoroughly covered."]}]',
#  'iteration': 4,
#  'max_cycles': 5,
#  'domain_fixed': False,
#  'previous_scores': {},
#  'history': [{'iteration': 0,
#    'domain': 'Unknown',
#    'scores': {},
#    'analysis_head': ''},
#   {'iteration': 0,
#    'domain': 'Customer Relationship Management (CRM)',
#    'scores': {'correctness': 4,
#     'relevance': 3,
#     'coverage': 3,
#     'insightfulness': 4,
#     'novelty': 4},
#    'analysis_head': 'The dataset comprises 3,117 customer records with 19 attributes each, focusing on various aspects of customer relationsh'},
#   {'iteration': 1,
#    'domain': 'Customer Relationship Management',
#    'scores': {'correctness': 4,
#     'relevance': 3,
#     'coverage': 3,
#     'insightfulness': 3,
#     'novelty': 3},
#    'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework. It includ'},
#   {'iteration': 2,
#    'domain': 'Customer Relationship Management (CRM)',
#    'scores': {'correctness': 4,
#     'relevance': 3,
#     'coverage': 3,
#     'insightfulness': 3,
#     'novelty': 3},
#    'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM context, featuring 3'},
#   {'iteration': 3,
#    'domain': 'Customer Relationship Management',
#    'scores': {'correctness': 4,
#     'relevance': 3,
#     'coverage': 3,
#     'insightfulness': 4,
#     'novelty': 4},
#    'analysis_head': 'The dataset provides a comprehensive view of customer interactions and characteristics within a CRM framework, focusing '},
#   {'iteration': 4,
#    'domain': 'Customer Relationship Management (CRM)',
#    'scores': {'correctness': 4,
#     'relevance': 3,
#     'coverage': 3,
#     'insightfulness': 3,
#     'novelty': 3},
#    'analysis_head': 'The dataset provides a comprehensive view of customer interactions and lifecycle within a CRM context, capturing 3,117 u'}],
#  'domain_info': {'domain': 'Customer Relationship Management (CRM)',
#   'definition': 'Customer Relationship Management (CRM) refers to the practices, strategies, and technologies that companies use to manage and analyze customer interactions and data throughout the customer lifecycle, with the goal of improving customer service relationships and assisting in customer retention and driving sales growth.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Customer_relationship_management'},
#  'concepts': [{'concepts': ['Customer Lifecycle Management',
#     'Customer Retention Strategies',
#     'Sales Growth Techniques',
#     'Customer Interaction Analysis',
#     'CRM Technologies',
#     'Customer Service Improvement']}],
#  'analysis': {'domain': 'Customer Relationship Management (CRM)',
#   'core_concepts': ['Customer Lifecycle Management',
#    'Customer Retention Strategies',
#    'Sales Growth Techniques',
#    'Customer Interaction Analysis',
#    'CRM Technologies',
#    'Customer Service Improvement'],
#   'analysis': {'descriptive': "The dataset provides a comprehensive view of customer interactions and lifecycle within a CRM context, capturing 3,117 unique customer records across 19 attributes. Key metrics include 'Periods Active', 'Revenue, Total', and 'Expected CLV', which offer insights into customer engagement and financial contributions. The data reveals that most customers are relatively new, with an average of 1.97 periods active, and a significant portion of revenue is derived from 'Maker Revenue'. The dataset also highlights the diversity in acquisition channels and customer demographics, such as region and company size, which can influence customer behavior and value.",
#    'predictive': "Predictive analysis could focus on identifying factors that contribute to higher 'Expected CLV' and customer retention. By examining correlations between 'Acquisition Channel', 'Premium (Y/N)', and 'Periods Active', we can develop models to predict customer churn and lifetime value. For instance, customers acquired through internal channels and those with premium status may exhibit higher retention rates and CLV. Additionally, analyzing the impact of 'No. Maker Contracts' and 'No. Advanced Contracts' on revenue streams could uncover strategies to optimize contract offerings and enhance customer profitability.",
#    'domain_related': "In the CRM domain, understanding customer lifecycle stages and retention strategies is crucial. This dataset provides a foundation for exploring how different acquisition channels and customer demographics affect retention and sales growth. The high variance in 'Expected CLV' suggests opportunities for targeted customer service improvements and personalized marketing strategies. By leveraging CRM technologies to analyze 'Customer ID' and 'Period Acquired', companies can tailor their engagement approaches, focusing on high-value customers and optimizing resource allocation to maximize sales growth and customer satisfaction."}},
#  'evaluation': 'The evaluation assesses the accuracy and depth of the domain and analysis provided for a dataset.',
#  'scores': {'correctness': 4,
#   'relevance': 3,
#   'coverage': 3,
#   'insightfulness': 3,
#   'novelty': 3},
#  'domain_ok': True,
#  'concepts_ok': True}

# %%
# If you want to save the results to a file:
from agents.domain_detector_wrap import NumpyEncoder


with open("exp01_domain_stim_hartnow_insight.json", "w") as f:
    json.dump(result, f, indent=2, cls=NumpyEncoder)
